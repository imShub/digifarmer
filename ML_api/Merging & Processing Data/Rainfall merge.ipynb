# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score

# %%
df = pd.read_csv("apy.csv")
data = df.dropna()
data
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production
# 0                  Arecanut    1254.0      2000.0
# ...

# %%
data1=data.sort_values(by=['Crop_Year'])
data1
# Out:
#          State_Name       District_Name  Crop_Year       Season  \
# 64403       Gujarat       SURENDRANAGAR       1997  Rabi
# 236503  West Bengal  24 PARAGANAS NORTH       1997  Whole Year
# 236504  West Bengal  24 PARAGANAS NORTH       1997  Winter
# 84376     Karnataka         CHITRADURGA       1997  Whole Year
# 84375     Karnataka         CHITRADURGA       1997  Whole Year
# ...             ...                 ...        ...          ...
# 156699       Odisha          MAYURBHANJ       2015  Winter
# 156700       Odisha          MAYURBHANJ       2015  Winter
# 156701       Odisha          MAYURBHANJ       2015  Winter
# 156703       Odisha          MAYURBHANJ       2015  Winter
# 152235       Odisha      JAGATSINGHAPUR       2015  Summer
#
#                      Crop      Area  Production
# 64403               Wheat   22500.0     46800.0
# 236503           Turmeric     820.0      1701.0
# 236504               Rice  193202.0    381990.0
# ...

# %%
raindata = pd.read_csv("rainfall in india 1901-2015.csv")

# %%
list(raindata[(raindata['SUBDIVISION']=="KERALA") & \
                                   (raindata['YEAR']==2011)]['ANNUAL'])[0]
# Out:
# 3035.1

# %%
raindata = raindata[raindata['YEAR']>1996]

# %%
raindata
# Out:
#                     SUBDIVISION  YEAR   JAN   FEB    MAR    APR    MAY    JUN  \
# 91    ANDAMAN & NICOBAR ISLANDS  1997   9.5   0.0    0.2   15.6  281.1  199.5
# 92    ANDAMAN & NICOBAR ISLANDS  1998   0.9   0.0    0.0    0.0  348.9  600.0
# 93    ANDAMAN & NICOBAR ISLANDS  1999  46.8  44.6   14.2  270.6  257.4  295.0
# 94    ANDAMAN & NICOBAR ISLANDS  2000  53.0  59.0  171.3  218.1  422.8  357.0
# 95    ANDAMAN & NICOBAR ISLANDS  2001  89.0  15.7  143.3   30.1  705.3  370.7
# ...                         ...   ...   ...   ...    ...    ...    ...    ...
# 4111                LAKSHADWEEP  2011   5.1   2.8    3.1   85.9  107.2  153.6
# 4112                LAKSHADWEEP  2012  19.2   0.1    1.6   76.8   21.2  327.0
# 4113                LAKSHADWEEP  2013  26.2  34.4   37.5    5.3   88.3  426.2
# 4114                LAKSHADWEEP  2014  53.2  16.1    4.4   14.9   57.4  244.1
# 4115                LAKSHADWEEP  2015   2.2   0.5    3.7   87.1  133.1  296.6
#
# ...

# %%
rain["SUBDIVISION"].unique()# merged data set states
# Out:
# array(['ANDAMAN & NICOBAR ISLANDS', 'ARUNACHAL PRADESH', 'ORISSA',
#        'JHARKHAND', 'BIHAR', 'UTTARAKHAND', 'PUNJAB', 'HIMACHAL PRADESH',
#        'JAMMU & KASHMIR', 'CHHATTISGARH', 'TAMIL NADU', 'KERALA'],
#       dtype=object)

# %%
raindata.sort_values(by=['SUBDIVISION'])["SUBDIVISION"].unique() # actual rain data set states
# Out:
# array(['ANDAMAN & NICOBAR ISLANDS', 'ARUNACHAL PRADESH',
#        'ASSAM & MEGHALAYA', 'BIHAR', 'CHHATTISGARH',
#        'COASTAL ANDHRA PRADESH', 'COASTAL KARNATAKA',
#        'EAST MADHYA PRADESH', 'EAST RAJASTHAN', 'EAST UTTAR PRADESH',
#        'GANGETIC WEST BENGAL', 'GUJARAT REGION',
#        'HARYANA DELHI & CHANDIGARH', 'HIMACHAL PRADESH',
#        'JAMMU & KASHMIR', 'JHARKHAND', 'KERALA', 'KONKAN & GOA',
#        'LAKSHADWEEP', 'MADHYA MAHARASHTRA', 'MATATHWADA',
#        'NAGA MANI MIZO TRIPURA', 'NORTH INTERIOR KARNATAKA', 'ORISSA',
#        'PUNJAB', 'RAYALSEEMA', 'SAURASHTRA & KUTCH',
#        'SOUTH INTERIOR KARNATAKA', 'SUB HIMALAYAN WEST BENGAL & SIKKIM',
#        'TAMIL NADU', 'TELANGANA', 'UTTARAKHAND', 'VIDARBHA',
#        'WEST MADHYA PRADESH', 'WEST RAJASTHAN', 'WEST UTTAR PRADESH'],
#       dtype=object)

# %%
data["State_Name"].unique() # crop data set states
# Out:
# array(['Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir ', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana ',
#        'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal'],
#       dtype=object)

# %%
year=[1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015]

# %%
state1="West Bengal"
state2="GANGETIC WEST BENGAL"
for y in year:
    data.loc[(data['State_Name']==state1) & \
                              (data['Crop_Year']==y),'Rainfall']= \
            list(raindata[(raindata['SUBDIVISION']==state2) & \
                                   (raindata['YEAR']==y)]['ANNUAL'])[0]
data[data['State_Name']==state1]
# Out:
# C:\Users\rahul\Anaconda3\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#          State_Name       District_Name  Crop_Year       Season       Crop  \
# 236478  West Bengal  24 PARAGANAS NORTH       1997  Autumn            Rice
# 236479  West Bengal  24 PARAGANAS NORTH       1997  Kharif            Jute
# 236480  West Bengal  24 PARAGANAS NORTH       1997  Kharif           Mesta
# 236481  West Bengal  24 PARAGANAS NORTH       1997  Kharif            Urad
# 236482  West Bengal  24 PARAGANAS NORTH       1997  Rabi              Gram
# ...             ...                 ...        ...          ...        ...
# ...

# %%
state1="Uttar Pradesh"
state2="WEST UTTAR PRADESH"
state3="EAST UTTAR PRADESH"
for y in year:
    data.loc[(data['State_Name']==state1) & \
                              (data['Crop_Year']==y),'Rainfall']= \
            (list(raindata[(raindata['SUBDIVISION']==state2) & \
                                   (raindata['YEAR']==y)]['ANNUAL'])[0] + list(raindata[(raindata['SUBDIVISION']==state3) & \
                                                                                        (raindata['YEAR']==y)]['ANNUAL'])[0])/2
data[data['State_Name']==state1]
# Out:
# C:\Users\rahul\Anaconda3\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#            State_Name District_Name  Crop_Year       Season  \
# 198276  Uttar Pradesh          AGRA       1997  Kharif
# 198277  Uttar Pradesh          AGRA       1997  Kharif
# 198278  Uttar Pradesh          AGRA       1997  Kharif
# 198279  Uttar Pradesh          AGRA       1997  Kharif
# 198280  Uttar Pradesh          AGRA       1997  Kharif
# ...               ...           ...        ...          ...
# 231577  Uttar Pradesh      VARANASI       2014  Rabi
# 231578  Uttar Pradesh      VARANASI       2014  Summer
# 231579  Uttar Pradesh      VARANASI       2014  Summer
# ...

# %%
data
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production  Rainfall
# ...

# %%
data.to_csv('Crop Production With Rainfall.csv')

# %%
data["Crop"].unique()
# Out:
# array(['Arecanut', 'Other Kharif pulses', 'Rice', 'Banana', 'Cashewnut',
#        'Coconut ', 'Dry ginger', 'Sugarcane', 'Sweet potato', 'Tapioca',
#        'Black pepper', 'Dry chillies', 'other oilseeds', 'Turmeric',
#        'Maize', 'Moong(Green Gram)', 'Urad', 'Arhar/Tur', 'Groundnut',
#        'Sunflower', 'Bajra', 'Castor seed', 'Cotton(lint)', 'Horse-gram',
#        'Jowar', 'Korra', 'Ragi', 'Tobacco', 'Gram', 'Wheat', 'Masoor',
#        'Sesamum', 'Linseed', 'Safflower', 'Onion', 'other misc. pulses',
#        'Samai', 'Small millets', 'Coriander', 'Potato',
#        'Other  Rabi pulses', 'Soyabean', 'Beans & Mutter(Vegetable)',
#        'Bhindi', 'Brinjal', 'Citrus Fruit', 'Cucumber', 'Grapes', 'Mango',
#        'Orange', 'other fibres', 'Other Fresh Fruits', 'Other Vegetables',
#        'Papaya', 'Pome Fruit', 'Tomato', 'Mesta', 'Cowpea(Lobia)',
#        'Lemon', 'Pome Granet', 'Sapota', 'Cabbage', 'Rapeseed &Mustard',
# ...
